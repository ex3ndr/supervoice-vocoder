# %% [markdown]
# # Supervoice Vocoder evaluation
#
# This notebook gives you an opportunity to test vocoder. This notebook is runnin on CPU just in case if your GPUs are busy training.

# %%
import torch
import torchaudio
import torchaudio.transforms as T
import torchaudio.functional as F
from IPython.display import Audio, display
import matplotlib.pyplot as plt

# %%
# Model loading
model = torch.hub.load(repo_or_dir='ex3ndr/supervoice-vocoder', model='bigvsan')
# Out:
# Using cache found in /home/steve/.cache/torch/hub/ex3ndr_supervoice-vocoder_master

# %% [markdown]
# ## Load file
# You can provide any reasonable audio file to check re-synthesing it from Mel Spectogram

# %%
from ipywidgets import FileUpload
upload = FileUpload(multiple=False)
upload
# Out:
# FileUpload(value=(), description='Upload')

# %%
def load_mono_audio(path):
    # Load audio
    audio, sr = torchaudio.load(path)

    # Resample
    if sr != 24000:
        audio = resampler(sr, 24000, device)(audio)
        sr = 24000

    # Convert to mono
    if audio.shape[0] > 1:
        audio = audio.mean(dim=0, keepdim=True)

    # Convert to single dimension
    audio = audio[0]

    return audio

# Load
if len(upload.value) == 1:
    with open("eval_vocoder.out", "w+b") as i:
        i.write(upload.value[0].content)
    source = load_mono_audio("eval_vocoder.out")
else:
    source = load_mono_audio("./sample.wav")

# %% [markdown]
# ## Mel Spectogram
# This code shows how to configure mel spectogram that is compatible with this vocoder

# %%
def spectogram(src):
    # Hann Window
    window = torch.hann_window(1024)

    # STFT
    stft = torch.stft(src, 
        n_fft = 1024, 
        hop_length = 256, 
        win_length = 1024,
        window = window, 
        center = True,
        return_complex = True
    )

    # magnitudes = stft[..., :-1].abs() ** 2 # Power
    magnitudes = stft[..., :-1].abs() # Amplitude (used by BigVSAN)

    # Mel Bank
    mel_filters = F.melscale_fbanks(
            n_freqs=int(1024 // 2 + 1),
            sample_rate=24000,
            f_min=0,
            f_max=12000,
            n_mels=100,
            norm="slaney",
            mel_scale="slaney"
    ).transpose(-1, -2)
    mel_spec = (mel_filters @ magnitudes)

    # Log
    log_spec = torch.clamp(mel_spec, min=1e-10).log()

    return log_spec

spec = spectogram(source)

# %% [markdown]
# ## Resynthesing
# This code synthesizes sound back, first audio is the source audio (rescaled to match vocoder parameters) and recreated audio

# %%
resynth = model(spec.unsqueeze(0)).detach().squeeze(0)
display(Audio(data=source, rate=24000))
display(Audio(data=resynth, rate=24000))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# tensor([[-0.0010, -0.0024, -0.0026,  ..., -0.0025, -0.0023, -0.0023]])

# %%
e0 = torch.load("./bigvsan.pt", map_location='cpu')['generator']
e1 = torch.load("./bigvsan_no_norm_ok.pt", map_location='cpu')

def manual_remove_weight_norm(state_dict):
    for key in list(state_dict.keys()):  # list(...) to make a copy of keys
        if 'weight_v' in key:
            layer_base = key.rsplit('.', 1)[0]  # Get the base name of the layer
            g_key = f'{layer_base}.weight_g'
            if g_key in state_dict:
                v = state_dict[key]
                g = state_dict[g_key]
                # Compute the recombined weight with proper norm calculation
                norm = v.norm(2, dim=-1, keepdim=True)  # Assuming last dim for norm
                recombined_weight = v * (g / norm.expand_as(v))
                # Update the original weight and remove g and v
                state_dict[layer_base + '.weight'] = recombined_weight
                del state_dict[key]  # Remove weight_v
                del state_dict[g_key]  # Remove weight_g
    return state_dict

e00 = manual_remove_weight_norm(torch.load("./bigvsan.pt", map_location='cpu')['generator'])

# %%
for k in e1:
    v = (e1[k] - e00[k]).abs().max()
    if v > 0:
        print(k, v)
# Out:
# conv_pre.weight tensor(1.5578)
# ups.0.0.weight tensor(1.5023)
# ups.1.0.weight tensor(1.7622)
# ups.2.0.weight tensor(1.6154)
# ups.3.0.weight tensor(0.5248)
# ups.4.0.weight tensor(0.3663)
# ups.5.0.weight tensor(0.4274)
# resblocks.0.convs1.0.weight tensor(1.8410)
# resblocks.0.convs1.1.weight tensor(1.2006)
# resblocks.0.convs1.2.weight tensor(1.1234)
# resblocks.0.convs2.0.weight tensor(1.1003)
# resblocks.0.convs2.1.weight tensor(1.4996)
# resblocks.0.convs2.2.weight tensor(2.5157)
# resblocks.1.convs1.0.weight tensor(2.2503)
# resblocks.1.convs1.1.weight tensor(1.0618)
# resblocks.1.convs1.2.weight tensor(1.4948)
# resblocks.1.convs2.0.weight tensor(1.2837)
# resblocks.1.convs2.1.weight tensor(2.2779)
# resblocks.1.convs2.2.weight tensor(3.1590)
# resblocks.2.convs1.0.weight tensor(1.7225)
# resblocks.2.convs1.1.weight tensor(1.4418)
# resblocks.2.convs1.2.weight tensor(1.1042)
# resblocks.2.convs2.0.weight tensor(1.4634)
# resblocks.2.convs2.1.weight tensor(2.0598)
# resblocks.2.convs2.2.weight tensor(2.1984)
# resblocks.3.convs1.0.weight tensor(2.5042)
# resblocks.3.convs1.1.weight tensor(1.1986)
# resblocks.3.convs1.2.weight tensor(1.3077)
# resblocks.3.convs2.0.weight tensor(1.5632)
# resblocks.3.convs2.1.weight tensor(1.3531)
# resblocks.3.convs2.2.weight tensor(1.8310)
# resblocks.4.convs1.0.weight tensor(1.8197)
# resblocks.4.convs1.1.weight tensor(2.2365)
# resblocks.4.convs1.2.weight tensor(1.4709)
# resblocks.4.convs2.0.weight tensor(2.1260)
# resblocks.4.convs2.1.weight tensor(3.4798)
# resblocks.4.convs2.2.weight tensor(4.5273)
# resblocks.5.convs1.0.weight tensor(1.9075)
# resblocks.5.convs1.1.weight tensor(1.7382)
# resblocks.5.convs1.2.weight tensor(1.4590)
# resblocks.5.convs2.0.weight tensor(2.6656)
# resblocks.5.convs2.1.weight tensor(2.7485)
# resblocks.5.convs2.2.weight tensor(4.6542)
# resblocks.6.convs1.0.weight tensor(2.3332)
# resblocks.6.convs1.1.weight tensor(1.7189)
# resblocks.6.convs1.2.weight tensor(1.1699)
# resblocks.6.convs2.0.weight tensor(2.0289)
# resblocks.6.convs2.1.weight tensor(1.2776)
# resblocks.6.convs2.2.weight tensor(1.2692)
# resblocks.7.convs1.0.weight tensor(1.9406)
# resblocks.7.convs1.1.weight tensor(2.3896)
# resblocks.7.convs1.2.weight tensor(1.5265)
# resblocks.7.convs2.0.weight tensor(3.2771)
# resblocks.7.convs2.1.weight tensor(4.0682)
# resblocks.7.convs2.2.weight tensor(1.6589)
# resblocks.8.convs1.0.weight tensor(2.6956)
# resblocks.8.convs1.1.weight tensor(2.5430)
# resblocks.8.convs1.2.weight tensor(1.2210)
# resblocks.8.convs2.0.weight tensor(2.9400)
# resblocks.8.convs2.1.weight tensor(4.3713)
# resblocks.8.convs2.2.weight tensor(6.3429)
# resblocks.9.convs1.0.weight tensor(0.7667)
# resblocks.9.convs1.1.weight tensor(1.6853)
# resblocks.9.convs1.2.weight tensor(0.7530)
# resblocks.9.convs2.0.weight tensor(1.0296)
# resblocks.9.convs2.1.weight tensor(0.8564)
# resblocks.9.convs2.2.weight tensor(0.7056)
# resblocks.10.convs1.0.weight tensor(0.9084)
# resblocks.10.convs1.1.weight tensor(2.0037)
# resblocks.10.convs1.2.weight tensor(0.8341)
# resblocks.10.convs2.0.weight tensor(0.7308)
# resblocks.10.convs2.1.weight tensor(0.8220)
# resblocks.10.convs2.2.weight tensor(0.6543)
# resblocks.11.convs1.0.weight tensor(2.7909)
# resblocks.11.convs1.1.weight tensor(2.6347)
# resblocks.11.convs1.2.weight tensor(1.9789)
# resblocks.11.convs2.0.weight tensor(1.6839)
# resblocks.11.convs2.1.weight tensor(1.3564)
# resblocks.11.convs2.2.weight tensor(0.7278)
# resblocks.12.convs1.0.weight tensor(0.3887)
# resblocks.12.convs1.1.weight tensor(0.5707)
# resblocks.12.convs1.2.weight tensor(0.3369)
# resblocks.12.convs2.0.weight tensor(0.3816)
# resblocks.12.convs2.1.weight tensor(0.2956)
# resblocks.12.convs2.2.weight tensor(0.2404)
# resblocks.13.convs1.0.weight tensor(0.4256)
# resblocks.13.convs1.1.weight tensor(0.5097)
# resblocks.13.convs1.2.weight tensor(0.3933)
# resblocks.13.convs2.0.weight tensor(0.4435)
# resblocks.13.convs2.1.weight tensor(0.3132)
# resblocks.13.convs2.2.weight tensor(0.2718)
# resblocks.14.convs1.0.weight tensor(0.5362)
# resblocks.14.convs1.1.weight tensor(0.6924)
# resblocks.14.convs1.2.weight tensor(0.4755)
# resblocks.14.convs2.0.weight tensor(0.3031)
# resblocks.14.convs2.1.weight tensor(0.4416)
# resblocks.14.convs2.2.weight tensor(0.3395)
# resblocks.15.convs1.0.weight tensor(0.4407)
# resblocks.15.convs1.1.weight tensor(0.3447)
# resblocks.15.convs1.2.weight tensor(0.3958)
# resblocks.15.convs2.0.weight tensor(0.4137)
# resblocks.15.convs2.1.weight tensor(0.2972)
# resblocks.15.convs2.2.weight tensor(0.5152)
# resblocks.16.convs1.0.weight tensor(0.4554)
# resblocks.16.convs1.1.weight tensor(2.6647)
# resblocks.16.convs1.2.weight tensor(2.0827)
# resblocks.16.convs2.0.weight tensor(0.6234)
# resblocks.16.convs2.1.weight tensor(0.9386)
# resblocks.16.convs2.2.weight tensor(0.4350)
# resblocks.17.convs1.0.weight tensor(0.3970)
# resblocks.17.convs1.1.weight tensor(0.5392)
# resblocks.17.convs1.2.weight tensor(0.4515)
# resblocks.17.convs2.0.weight tensor(0.2765)
# resblocks.17.convs2.1.weight tensor(0.3108)
# resblocks.17.convs2.2.weight tensor(0.4138)
# conv_post.weight tensor(0.0052)

# %%
v = e0['conv_post.weight_v']
g = e0['conv_post.weight_g']
v_norm = torch.norm(v, p=2, dim=list(range(1, v.dim())), keepdim=True)
# v_norm = v_norm.expand_as(v)
cc = g * (v / v_norm)

print("source")
print(v)
print(g)
print(v_norm)
print(cc)

print("gen")
print(e1['conv_post.weight'])
print(e2['conv_post.weight'])
print(e00['conv_post.weight'])
# Out:
# source
# tensor([[[-0.0308, -0.0057,  0.0640,  0.0099, -0.0444, -0.0029,  0.0103],
#          [-0.0226, -0.0342, -0.0365, -0.0237,  0.0246,  0.0494,  0.0345],
#          [ 0.0065, -0.0014, -0.0038, -0.0020, -0.0052,  0.0123, -0.0054],
#          [-0.0122, -0.0232, -0.0290, -0.0345, -0.0298, -0.0241, -0.0140],
#          [ 0.0027, -0.0020, -0.0177,  0.0298, -0.0022, -0.0302,  0.0192],
#          [-0.0073, -0.0278,  0.0079,  0.0642,  0.0122, -0.0334, -0.0153],
#          [-0.0308, -0.0542, -0.0613, -0.0726, -0.0612, -0.0549, -0.0334],
#          [-0.0057,  0.0011,  0.0467, -0.0799,  0.0451, -0.0020, -0.0052],
#          [ 0.0311, -0.0107, -0.0583, -0.0124,  0.0530,  0.0199, -0.0230],
#          [-0.0086,  0.0416, -0.0683,  0.0493, -0.0143, -0.0045,  0.0044],
#          [ 0.0170,  0.0303,  0.0361,  0.0265, -0.0302, -0.0474, -0.0320],
#          [ 0.0071,  0.0005, -0.0527,  0.0878, -0.0431, -0.0066,  0.0070],
#          [ 0.0207,  0.0510, -0.0053, -0.0791, -0.0562,  0.0274,  0.0419],
#          [ 0.0134,  0.0303,  0.0385,  0.0480,  0.0424,  0.0357,  0.0239],
#          [ 0.0293,  0.0454,  0.0480,  0.0558,  0.0463,  0.0431,  0.0254],
#          [-0.0035, -0.0121, -0.0270, -0.0301, -0.0534, -0.0203, -0.0159],
#          [-0.0051, -0.0014,  0.0096,  0.0124,  0.0089,  0.0022, -0.0012],
#          [ 0.0039, -0.0208,  0.0416, -0.0505,  0.0346, -0.0065, -0.0023],
#          [ 0.0184,  0.0318,  0.0573,  0.0453,  0.0283,  0.0156,  0.0055],
#          [ 0.0089,  0.0340, -0.0522, -0.0367,  0.0563,  0.0013, -0.0114],
#          [-0.0317, -0.0585, -0.0417,  0.0275,  0.0415,  0.0403,  0.0229],
#          [-0.0290, -0.0157,  0.0390,  0.0356,  0.0135, -0.0249, -0.0176],
#          [ 0.0018, -0.0054,  0.0264, -0.0444, -0.0012,  0.0496, -0.0272],
#          [ 0.0322,  0.0519,  0.0269, -0.0288, -0.0327, -0.0283, -0.0217]]])
# tensor([[[0.0072]]])
# tensor([[[0.4374]]])
# tensor([[[-5.0922e-04, -9.3605e-05,  1.0572e-03,  1.6312e-04, -7.3339e-04,
#           -4.8413e-05,  1.7008e-04],
#          [-3.7344e-04, -5.6464e-04, -6.0263e-04, -3.9122e-04,  4.0702e-04,
#            8.1602e-04,  5.7006e-04],
#          [ 1.0758e-04, -2.3706e-05, -6.2389e-05, -3.3090e-05, -8.5586e-05,
#            2.0317e-04, -8.8805e-05],
#          [-2.0198e-04, -3.8315e-04, -4.7967e-04, -5.7050e-04, -4.9282e-04,
#           -3.9756e-04, -2.3066e-04],
#          [ 4.3951e-05, -3.3344e-05, -2.9330e-04,  4.9281e-04, -3.6347e-05,
#           -4.9852e-04,  3.1714e-04],
#          [-1.2022e-04, -4.5927e-04,  1.3009e-04,  1.0617e-03,  2.0117e-04,
#           -5.5282e-04, -2.5370e-04],
#          [-5.0918e-04, -8.9562e-04, -1.0134e-03, -1.2009e-03, -1.0110e-03,
#           -9.0824e-04, -5.5266e-04],
#          [-9.3811e-05,  1.7543e-05,  7.7249e-04, -1.3199e-03,  7.4586e-04,
#           -3.3533e-05, -8.5328e-05],
#          [ 5.1413e-04, -1.7716e-04, -9.6304e-04, -2.0471e-04,  8.7663e-04,
#            3.2953e-04, -3.7998e-04],
#          [-1.4291e-04,  6.8786e-04, -1.1287e-03,  8.1572e-04, -2.3612e-04,
#           -7.3853e-05,  7.2091e-05],
#          [ 2.8030e-04,  5.0058e-04,  5.9691e-04,  4.3750e-04, -4.9903e-04,
#           -7.8348e-04, -5.2968e-04],
#          [ 1.1669e-04,  8.3365e-06, -8.7037e-04,  1.4510e-03, -7.1223e-04,
#           -1.0856e-04,  1.1511e-04],
#          [ 3.4186e-04,  8.4290e-04, -8.8118e-05, -1.3069e-03, -9.2903e-04,
#            4.5256e-04,  6.9314e-04],
#          [ 2.2213e-04,  5.0133e-04,  6.3565e-04,  7.9388e-04,  7.0075e-04,
#            5.8931e-04,  3.9505e-04],
#          [ 4.8496e-04,  7.5021e-04,  7.9339e-04,  9.2205e-04,  7.6502e-04,
#            7.1304e-04,  4.1925e-04],
#          [-5.7647e-05, -2.0024e-04, -4.4686e-04, -4.9689e-04, -8.8331e-04,
#           -3.3546e-04, -2.6299e-04],
#          [-8.3673e-05, -2.3680e-05,  1.5929e-04,  2.0428e-04,  1.4650e-04,
#            3.6433e-05, -2.0046e-05],
#          [ 6.4398e-05, -3.4319e-04,  6.8712e-04, -8.3402e-04,  5.7185e-04,
#           -1.0688e-04, -3.8755e-05],
#          [ 3.0357e-04,  5.2545e-04,  9.4770e-04,  7.4926e-04,  4.6811e-04,
#            2.5725e-04,  9.1074e-05],
#          [ 1.4772e-04,  5.6253e-04, -8.6212e-04, -6.0698e-04,  9.2988e-04,
#            2.0694e-05, -1.8765e-04],
#          [-5.2419e-04, -9.6764e-04, -6.8900e-04,  4.5471e-04,  6.8561e-04,
#            6.6612e-04,  3.7929e-04],
#          [-4.7893e-04, -2.5936e-04,  6.4533e-04,  5.8924e-04,  2.2384e-04,
#           -4.1145e-04, -2.9071e-04],
#          [ 2.9917e-05, -8.9317e-05,  4.3671e-04, -7.3316e-04, -2.0515e-05,
#            8.1965e-04, -4.4883e-04],
#          [ 5.3154e-04,  8.5815e-04,  4.4470e-04, -4.7679e-04, -5.4012e-04,
#           -4.6808e-04, -3.5822e-04]]])
# gen
# tensor([[[-5.0922e-04, -9.3605e-05,  1.0572e-03,  1.6312e-04, -7.3339e-04,
#           -4.8413e-05,  1.7008e-04],
#          [-3.7344e-04, -5.6464e-04, -6.0263e-04, -3.9122e-04,  4.0702e-04,
#            8.1602e-04,  5.7006e-04],
#          [ 1.0758e-04, -2.3706e-05, -6.2389e-05, -3.3090e-05, -8.5586e-05,
#            2.0317e-04, -8.8805e-05],
#          [-2.0198e-04, -3.8315e-04, -4.7967e-04, -5.7050e-04, -4.9282e-04,
#           -3.9756e-04, -2.3066e-04],
#          [ 4.3951e-05, -3.3344e-05, -2.9330e-04,  4.9281e-04, -3.6347e-05,
#           -4.9852e-04,  3.1714e-04],
#          [-1.2022e-04, -4.5927e-04,  1.3009e-04,  1.0617e-03,  2.0117e-04,
#           -5.5282e-04, -2.5370e-04],
#          [-5.0918e-04, -8.9562e-04, -1.0134e-03, -1.2009e-03, -1.0110e-03,
#           -9.0824e-04, -5.5266e-04],
#          [-9.3811e-05,  1.7543e-05,  7.7249e-04, -1.3199e-03,  7.4586e-04,
#           -3.3533e-05, -8.5328e-05],
#          [ 5.1413e-04, -1.7716e-04, -9.6304e-04, -2.0471e-04,  8.7663e-04,
#            3.2953e-04, -3.7998e-04],
#          [-1.4291e-04,  6.8786e-04, -1.1287e-03,  8.1572e-04, -2.3612e-04,
#           -7.3853e-05,  7.2091e-05],
#          [ 2.8030e-04,  5.0058e-04,  5.9691e-04,  4.3750e-04, -4.9903e-04,
#           -7.8348e-04, -5.2968e-04],
#          [ 1.1669e-04,  8.3365e-06, -8.7037e-04,  1.4510e-03, -7.1223e-04,
#           -1.0856e-04,  1.1511e-04],
#          [ 3.4186e-04,  8.4290e-04, -8.8118e-05, -1.3069e-03, -9.2903e-04,
#            4.5256e-04,  6.9314e-04],
#          [ 2.2213e-04,  5.0133e-04,  6.3565e-04,  7.9388e-04,  7.0075e-04,
#            5.8931e-04,  3.9505e-04],
#          [ 4.8496e-04,  7.5021e-04,  7.9339e-04,  9.2205e-04,  7.6502e-04,
#            7.1304e-04,  4.1925e-04],
#          [-5.7647e-05, -2.0024e-04, -4.4686e-04, -4.9689e-04, -8.8331e-04,
#           -3.3546e-04, -2.6299e-04],
#          [-8.3673e-05, -2.3680e-05,  1.5929e-04,  2.0428e-04,  1.4650e-04,
#            3.6433e-05, -2.0046e-05],
#          [ 6.4398e-05, -3.4319e-04,  6.8712e-04, -8.3402e-04,  5.7185e-04,
#           -1.0688e-04, -3.8755e-05],
#          [ 3.0357e-04,  5.2545e-04,  9.4770e-04,  7.4926e-04,  4.6811e-04,
#            2.5725e-04,  9.1074e-05],
#          [ 1.4772e-04,  5.6253e-04, -8.6212e-04, -6.0698e-04,  9.2988e-04,
#            2.0694e-05, -1.8765e-04],
#          [-5.2419e-04, -9.6764e-04, -6.8900e-04,  4.5471e-04,  6.8561e-04,
#            6.6612e-04,  3.7929e-04],
#          [-4.7893e-04, -2.5936e-04,  6.4533e-04,  5.8924e-04,  2.2384e-04,
#           -4.1145e-04, -2.9071e-04],
#          [ 2.9917e-05, -8.9317e-05,  4.3671e-04, -7.3316e-04, -2.0515e-05,
#            8.1965e-04, -4.4883e-04],
#          [ 5.3154e-04,  8.5815e-04,  4.4470e-04, -4.7679e-04, -5.4012e-04,
#           -4.6808e-04, -3.5822e-04]]])
# tensor([[[-2.6158e-03, -4.8083e-04,  5.4305e-03,  8.3790e-04, -3.7673e-03,
#           -2.4869e-04,  8.7368e-04],
#          [-1.8498e-03, -2.7968e-03, -2.9850e-03, -1.9378e-03,  2.0161e-03,
#            4.0419e-03,  2.8236e-03],
#          [ 2.8671e-03, -6.3177e-04, -1.6627e-03, -8.8186e-04, -2.2809e-03,
